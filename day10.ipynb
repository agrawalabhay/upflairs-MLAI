# %%
import cv2
import skimage as skimage
import matplotlib.pyplot as plt

# %%
img = cv2.imread('hanuman.webp')
cv2.imshow('Hanuman',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (225, 195, 3)

# %%
img
# Out:
# array([[[ 16,  22,  32],
#         [ 25,  30,  41],
#         [ 28,  34,  44],
#         ...,
#         [179, 237, 241],
#         [182, 239, 244],
#         [184, 242, 246]],
#
#        [[ 16,  22,  32],
#         [ 25,  30,  41],
#         [ 28,  34,  44],
#         ...,
#         [172, 230, 234],
#         [173, 231, 235],
#         [176, 234, 238]],
#
#        [[ 16,  22,  32],
#         [ 25,  30,  41],
#         [ 28,  34,  44],
#         ...,
#         [167, 227, 231],
#         [168, 228, 232],
#         [170, 230, 234]],
#
#        ...,
#
#        [[  8,   8,   8],
#         [  5,   5,   5],
#         [  7,   7,   7],
#         ...,
#         [  7,   7,   7],
#         [  7,   7,   7],
#         [ 10,  10,  10]],
#
#        [[  9,   9,   9],
#         [  5,   5,   5],
#         [  7,   7,   7],
#         ...,
#         [  7,   7,   7],
#         [  7,   7,   7],
#         [ 12,  12,  12]],
#
#        [[ 12,  12,  12],
#         [  5,   5,   5],
#         [  7,   7,   7],
# ...

# %%
img1 = plt.imread('hanuman.webp')
plt.imshow(img1)
